# %%
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
import random

# %matplotlib inline

fig = pyplot.figure()
ax = Axes3D(fig)

sequence_containing_x_vals = list(range(0, 100))
sequence_containing_y_vals = list(range(0, 100))
sequence_containing_z_vals = list(range(0, 100))

random.shuffle(sequence_containing_x_vals)
random.shuffle(sequence_containing_y_vals)
random.shuffle(sequence_containing_z_vals)

ax.scatter(sequence_containing_x_vals, sequence_containing_y_vals, sequence_containing_z_vals)
pyplot.show()

# %%
from sklearn.manifold import TSNE
import pickle
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import cm
sns.set(style='white', context='notebook', rc={'figure.figsize':(14,10)})

# %%
data = pickle.load(open('../output/scene_resnet_feats_train.pkl','rb'))
X = np.array([x[2] for x in data])
y = np.array([x[1] for x in data])

# %%
embedding = TSNE(n_components=3, verbose=True).fit_transform(X)
embedding.shape
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 139992 samples in 5.253s...
# [t-SNE] Computed neighbors for 139992 samples in 15135.750s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 139992
# [t-SNE] Computed conditional probabilities for sample 2000 / 139992
# [t-SNE] Computed conditional probabilities for sample 3000 / 139992
# [t-SNE] Computed conditional probabilities for sample 4000 / 139992
# [t-SNE] Computed conditional probabilities for sample 5000 / 139992
# [t-SNE] Computed conditional probabilities for sample 6000 / 139992
# [t-SNE] Computed conditional probabilities for sample 7000 / 139992
# [t-SNE] Computed conditional probabilities for sample 8000 / 139992
# [t-SNE] Computed conditional probabilities for sample 9000 / 139992
# [t-SNE] Computed conditional probabilities for sample 10000 / 139992
# [t-SNE] Computed conditional probabilities for sample 11000 / 139992
# [t-SNE] Computed conditional probabilities for sample 12000 / 139992
# ...

# %%
x_vals, y_vals, z_vals = zip(*embedding)

# %%
len(x_vals)
# Out:
# 139992

# %%
plt.scatter(x_vals, y_vals, z_vals, c=y, cmap='jet')
plt.colorbar(ticks=range(12))
plt.show()
# Out:
# /home/zal/.local/lib/python3.6/site-packages/matplotlib/collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
plt.colo
